# %%
from spending_tracker.data_ingestion import pdf_parsing
from spending_tracker.data_processing import statements
from pathlib import Path

# %%
data_home = Path().resolve().parent / "data"

# %%
statements.parse_and_clean(data_home)
