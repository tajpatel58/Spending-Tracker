# %%
from spending_tracker.database import supabase_client
from spending_tracker.database import transactions
from pathlib import Path

# %%
db_client = supabase_client.load_supabase_client()

# %%
labelled_examples = transactions.fetch_manually_categorised_transactions_as_dict(db_client)

# %%
print(labelled_examples)
# Out:
# [{'merchant': 'APPLE.COM/BILL 08001076285 IE', 'amount': -6.99, 'category': 'subscriptions'}, {'merchant': 'O2', 'amount': -10.5, 'category': 'subscriptions'}, {'merchant': 'THE GYM LTD', 'amount': -18.99, 'category': 'health'}, {'merchant': 'Cards Direct Borehamwood GB', 'amount': -1.29, 'category': 'shopping'}, {'merchant': "Pepe's Peri Peri London GB", 'amount': -17.09, 'category': 'dining'}, {'merchant': 'APPLE.COM/BILL 08001076285 IE 0000000000000000', 'amount': -8.99, 'category': 'subscriptions'}, {'merchant': 'VEGGIE WOK LONDON GB', 'amount': -25.9, 'category': 'dining'}, {'merchant': 'APPLE.COM/BILL 08001076285 IE 0000000000000000', 'amount': -1.79, 'category': 'subscriptions'}, {'merchant': 'SOUTHERN FUNDING', 'amount': 2947.94, 'category': 'salary'}, {'merchant': 'BANANA TREE SOHO GB', 'amount': -66.71, 'category': 'birthday/gifts'}, {'merchant': 'TESCO STORES 5620 LONDON GB', 'amount': -3.8, 'category': 'groceries'}, {'merchant': 'MORRISONS QUEENSBURY - 30 QUEENSBURY GB', 'amount': -9.36, 'category': 'groceries'}, {'merchant': 'ASDA SUPERSTORE COLINDALE GB', 'amount': -5.0, 'category': 'groceries'}, {'merchant': 'FUNKY PIGEON BRISTOL GB', 'amount': -7.29, 'category': 'shopping'}, {'merchant': 'MARKS&SPENCER PLC LONDON GB', 'amount': -7.43, 'category': 'groceries'}, {'merchant': 'M&S SALFORD INTERNET GB', 'amount': -25.0, 'category': 'groceries'}, {'merchant': 'Dunelm SoftFurnishings Leicester GB', 'amount': -30.0, 'category': 'shopping'}, {'merchant': 'MORRISONS QUEENSBURY - 30 QUEENSBURY GB', 'amount': -10.75, 'category': 'groceries'}, {'merchant': 'MARKS&SPENCER PLC INTERNET GB', 'amount': -25.0, 'category': 'groceries'}, {'merchant': 'MORRISONS QUEENSBURY - 30 QUEENSBURY GB', 'amount': -8.35, 'category': 'groceries'}, {'merchant': 'MORRISONS QUEENSBURY - 30 QUEENSBURY GB', 'amount': -6.57, 'category': 'groceries'}, {'merchant': 'VB & SONS HARROW GB', 'amount': -7.31, 'category': 'groceries'}, {'merchant': 'DOMINO S PIZZA MILTON KEYNES GB', 'amount': -15.76, 'category': 'dining'}, {'merchant': 'MARKS&SPENCER PLC LONDON GB', 'amount': -18.11, 'category': 'groceries'}, {'merchant': 'TESCO STORES 2126 BOREHAMWOOD GB', 'amount': -3.39, 'category': 'groceries'}, {'merchant': 'ICELAND KINGSBURY GB', 'amount': -4.75, 'category': 'groceries'}, {'merchant': 'MORRISONS QUEENSBURY - 30 QUEENSBURY GB', 'amount': -7.05, 'category': 'groceries'}, {'merchant': 'LAHORE SPICE 3 LONDON GB', 'amount': -57.8, 'category': 'dining'}, {'merchant': 'DOMINO S PIZZA MILTON KEYNES GB', 'amount': -8.77, 'category': 'dining'}, {'merchant': 'TESCO STORES 5620 LONDON GB', 'amount': -3.15, 'category': 'groceries'}, {'merchant': 'MORRISONS QUEENSBURY - 30 QUEENSBURY GB', 'amount': -4.8, 'category': 'groceries'}, {'merchant': 'WM MORRISONS STORES - Q', 'amount': -6.5, 'category': 'groceries'}, {'merchant': 'WM MORRISONS STORES - Q', 'amount': -3.5, 'category': 'groceries'}, {'merchant': 'FS2307 Queensbury 73156', 'amount': -60.0, 'category': 'transport'}, {'merchant': 'TESCO STORE 2126 2126TE', 'amount': -4.5, 'category': 'groceries'}, {'merchant': 'AMAZON.CO.UK*5Q00B9ZR5', 'amount': -39.42, 'category': 'shopping'}, {'merchant': 'ASDA STORES', 'amount': -11.0, 'category': 'groceries'}, {'merchant': 'TESCO STORE 2126 2126TE', 'amount': -8.0, 'category': 'groceries'}, {'merchant': 'AMZNMKTPLACE*SC2GE5OF5', 'amount': -18.99, 'category': 'shopping'}, {'merchant': 'APPLE.COM/BILL 08001076285 IE', 'amount': -6.99, 'category': 'subscriptions'}, {'merchant': 'O2', 'amount': -10.5, 'category': 'subscriptions'}, {'merchant': 'THE GYM LTD', 'amount': -18.99, 'category': 'health'}, {'merchant': 'AMAZON* JC35T2MU5 LONDON GB 0253', 'amount': -3.99, 'category': 'shopping'}, {'merchant': 'AMAZON* 1H5IT6V05 LONDON GB 0253', 'amount': -16.98, 'category': 'shopping'}, {'merchant': 'SAVERS HEALTH & BEAUTY BOREHAMWOOD GB', 'amount': -2.99, 'category': 'shopping'}, {'merchant': 'BOOTS, BOREHAMWOOD BOREHAMWOOD GB', 'amount': -3.5, 'category': 'shopping'}, {'merchant': ' ...

# %%
print(len(labelled_examples))
# Out:
# 100
