# %%
from spending_tracker.database import supabase_client
from spending_tracker.database import transactions
from spending_tracker.data_ingestion import csv_parsing
from pathlib import Path
import pandas as pd

# %%
db_client = supabase_client.load_supabase_client()

# %%
processed_transactions_data_home = Path().resolve().parent / "data" / "transactions" / "processed"
print(processed_transactions_data_home)
# Out:
# /Users/taj/Documents/Spending-Tracker-Agent/data/transactions/processed

# %%
transactions_df = csv_parsing.load_processed_transactions(processed_transactions_data_home)

# %%
transactions_df.head(10)
# Out:
#                                             event_id        date  \
# 0  fb641f97fd734c92205170a5df4c5800a8d0d9b6dc112a...  2026-07-01
# 1  1051b7a497136c7793f0d3623f8ad663d0363e48a1ea2c...  2026-07-06
# 2  adc90a862debcae27e6e8556070de511741fd4435287f1...  2026-07-06
# 3  f1211216911d575fa379d31f2a2df6ab70550b111c8f1a...  2026-07-07
# 4  3dca9a0916bf03484ede934699ed1a7f4c145be65b6f34...  2026-07-08
# 5  cb9070465db36417dfc131d6628e2695d1f42a653aaecd...  2026-07-09
# 6  abf7023cf07a3807145f9eb57a3095d41f1a5d0b241049...  2026-07-10
# 7  574fd36a6fca46a5d30eecda1bf0e4a503d2ab43fa21bf...  2026-07-10
# 8  c295c245e8953ac807541880c90622b937a03507276db9...  2026-07-10
# 9  6997a77081a3e9f431714f2e05029eafa839becc559232...  2026-07-13
#
#                                    merchant          type  category   amount  \
# 0                           Interest earned      Interest       NaN   -21.38
# 1                        From Taj's Account      Transfer       NaN -1600.00
# 2  To AMERICAN EXP 3773 - PB658258159641217       Payment       NaN  2084.16
# 3                      To Taj Patel - Chase       Payment       NaN   500.00
# 4              To Vithushan Maurice - Chase       Payment       NaN  1000.00
# 5        From GUJRATI ARYA - KHSECDEP180626       Payment       NaN  -500.00
# 6          The Gym Group - A444110C-THE-GYM  Direct Debit       NaN    19.99
# 7                    From Taj Patel - CHASE       Payment       NaN  -471.30
# 8          From PAYPAL - PPWDL5U52222228JF8       Payment       NaN  -491.00
# 9                    From PARVEZ S A - FOOD       Payment       NaN  -235.00
#
#    other_details  account_id user                              raw_merchant  \
# 0            NaN    69448147  Taj                           Interest earned
# 1            NaN    69448147  Taj                        From Taj's Account
# 2            NaN    69448147  Taj  To AMERICAN EXP 3773 - PB658258159641217
# 3            NaN    69448147  Taj                      To Taj Patel - Chase
# 4            NaN    69448147  Taj              To Vithushan Maurice - Chase
# 5            NaN    69448147  Taj        From GUJRATI ARYA - KHSECDEP180626
# 6            NaN    69448147  Taj          The Gym Group - A444110C-THE-GYM
# 7            NaN    69448147  Taj                    From Taj Patel - CHASE
# 8            NaN    69448147  Taj          From PAYPAL - PPWDL5U52222228JF8
# 9            NaN    69448147  Taj                    From PARVEZ S A - FOOD
#
#    raw_amount        bank
# 0      -21.38  Chase Bank
# 1    -1600.00  Chase Bank
# 2     2084.16  Chase Bank
# 3      500.00  Chase Bank
# 4     1000.00  Chase Bank
# 5     -500.00  Chase Bank
# 6       19.99  Chase Bank
# 7     -471.30  Chase Bank
# 8     -491.00  Chase Bank
# 9     -235.00  Chase Bank

# %%
transactions.upload_transactions_to_db(transactions_df, db_client)
# Out:
# APIResponse(data=[{'event_id': 'fb641f97fd734c92205170a5df4c5800a8d0d9b6dc112a15102a7f45962bb14e', 'date': '2026-07-01', 'merchant': 'Interest earned', 'type': 'Interest', 'category': None, 'amount': -21.38, 'other_details': None, 'account_id': 69448147, 'user': 'Taj', 'raw_merchant': 'Interest earned', 'raw_amount': -21.38, 'bank': 'Chase Bank', 'updated_at': '2026-08-20T11:43:44.774874+00:00'}, {'event_id': '1051b7a497136c7793f0d3623f8ad663d0363e48a1ea2c7a45cb23c7756fd41f', 'date': '2026-07-06', 'merchant': "From Taj's Account", 'type': 'Transfer', 'category': None, 'amount': -1600.0, 'other_details': None, 'account_id': 69448147, 'user': 'Taj', 'raw_merchant': "From Taj's Account", 'raw_amount': -1600.0, 'bank': 'Chase Bank', 'updated_at': '2026-08-20T11:43:44.774874+00:00'}, {'event_id': 'adc90a862debcae27e6e8556070de511741fd4435287f1f054851f947aeb84fa', 'date': '2026-07-06', 'merchant': 'To AMERICAN EXP 3773 - PB658258159641217', 'type': 'Payment', 'category': None, 'amount': 2084.16, 'other_details': None, 'account_id': 69448147, 'user': 'Taj', 'raw_merchant': 'To AMERICAN EXP 3773 - PB658258159641217', 'raw_amount': 2084.16, 'bank': 'Chase Bank', 'updated_at': '2026-08-20T11:43:44.774874+00:00'}, {'event_id': 'f1211216911d575fa379d31f2a2df6ab70550b111c8f1a6b1a1e7e91c48a5ff5', 'date': '2026-07-07', 'merchant': 'To Taj Patel - Chase', 'type': 'Payment', 'category': None, 'amount': 500.0, 'other_details': None, 'account_id': 69448147, 'user': 'Taj', 'raw_merchant': 'To Taj Patel - Chase', 'raw_amount': 500.0, 'bank': 'Chase Bank', 'updated_at': '2026-08-20T11:43:44.774874+00:00'}, {'event_id': '3dca9a0916bf03484ede934699ed1a7f4c145be65b6f3495789f5d35c96279ae', 'date': '2026-07-08', 'merchant': 'To Vithushan Maurice - Chase', 'type': 'Payment', 'category': None, 'amount': 1000.0, 'other_details': None, 'account_id': 69448147, 'user': 'Taj', 'raw_merchant': 'To Vithushan Maurice - Chase', 'raw_amount': 1000.0, 'bank': 'Chase Bank', 'updated_at': '2026-08-20T11:43:44.774874+00:00'}, {'event_id': 'cb9070465db36417dfc131d6628e2695d1f42a653aaecd4d9538da336d9c415e', 'date': '2026-07-09', 'merchant': 'From GUJRATI ARYA - KHSECDEP180626', 'type': 'Payment', 'category': None, 'amount': -500.0, 'other_details': None, 'account_id': 69448147, 'user': 'Taj', 'raw_merchant': 'From GUJRATI ARYA - KHSECDEP180626', 'raw_amount': -500.0, 'bank': 'Chase Bank', 'updated_at': '2026-08-20T11:43:44.774874+00:00'}, {'event_id': 'abf7023cf07a3807145f9eb57a3095d41f1a5d0b2410499193d96e4cca8d8261', 'date': '2026-07-10', 'merchant': 'The Gym Group - A444110C-THE-GYM', 'type': 'Direct Debit', 'category': None, 'amount': 19.99, 'other_details': None, 'account_id': 69448147, 'user': 'Taj', 'raw_merchant': 'The Gym Group - A444110C-THE-GYM', 'raw_amount': 19.99, 'bank': 'Chase Bank', 'updated_at': '2026-08-20T11:43:44.774874+00:00'}, {'event_id': '574fd36a6fca46a5d30eecda1bf0e4a503d2ab43fa21bf5277cafbfa1ef7db46', 'date': '2026-07-10', 'merchant': 'From Taj Patel - CHASE', 'type': 'Payment', 'category': None, 'amount': -471.3, 'other_details': None, 'account_id': 69448147, 'user': 'Taj', 'raw_merchant': 'From Taj Patel - CHASE', 'raw_amount': -471.3, 'bank': 'Chase Bank', 'updated_at': '2026-08-20T11:43:44.774874+00:00'}, {'event_id': 'c295c245e8953ac807541880c90622b937a03507276db9ae44d8e7af87696bbf', 'date': '2026-07-10', 'merchant': 'From PAYPAL - PPWDL5U52222228JF8', 'type': 'Payment', 'category': None, 'amount': -491.0, 'other_details': None, 'account_id': 69448147, 'user': 'Taj', 'raw_merchant': 'From PAYPAL - PPWDL5U52222228JF8', 'raw_amount': -491.0, 'bank': 'Chase Bank', 'updated_at': '2026-08-20T11:43:44.774874+00:00'}, {'event_id': '6997a77081a3e9f431714f2e05029eafa839becc5592329b21c2af61f3c35d55', 'date': '2026-07-13', 'merchant': 'From PARVEZ S A - FOOD', 'type': 'Payment', 'category': None, 'amount': -235.0, 'other_details': None, 'account_id': 69448147, 'user': 'Taj', 'raw_merchant': 'From PARVEZ S A - FOOD', 'raw_amount': -235.0, 'bank': 'Cha ...
