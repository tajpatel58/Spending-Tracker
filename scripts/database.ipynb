# %%
from spending_tracker.database import supabase_client
from spending_tracker.database import transactions
from spending_tracker.data_ingestion import csv_parsing
from pathlib import Path
import pandas as pd

# %%
db_client = supabase_client.load_supabase_client()

# %%
processed_transactions_data_home = Path().resolve().parent / "data" / "transactions" / "processed"
print(processed_transactions_data_home)
# Out:
# /Users/taj/Documents/Spending-Tracker-Agent/data/transactions/processed

# %%
transactions_df = csv_parsing.load_processed_transactions(processed_transactions_data_home)

# %%
transactions_df.head(10)
# Out:
#                                             event_id        date  \
# 0  32be75dda07543c23283228d4342b3b38838590919e9a6...  2026-07-01
# 1  b404beb6dd8ed159f2a4ff8921a33c380d0296d5670d52...  2026-07-01
# 2  799c91ecbf5ba6613b5e4bdc654cde7b4be779b033dce2...  2026-07-02
# 3  8f853d47ff5f26aa3b2bb8c80951740773f73fb420a760...  2026-07-02
# 4  45a92998d423bb8a994a555f2df213a48779128bcde2d5...  2026-07-03
# 5  c294d65759b5840c4573faefaf89c5382cb1c5178aa353...  2026-07-03
# 6  60f39397c21309790ba457036cb751aa3dbe4005bdf84c...  2026-07-03
# 7  de64913b0df7e9b86868430712e47b0d4c9c4b0b556bea...  2026-07-04
# 8  2fa016d301a22588e5bb87084311786bff383548948d7d...  2026-07-04
# 9  140650226632d10a80d6e2b5222a274956d4944a20e3cd...  2026-07-04
#
#                  merchant      type  category  amount  \
# 0               Samanvaya  Purchase       NaN  -35.82
# 1  Equipoise Resort & Spa  Purchase       NaN   -6.63
# 2               Samanvaya  Purchase       NaN   -1.80
# 3               Samanvaya  Purchase       NaN  -11.54
# 4               Samanvaya  Purchase       NaN  -63.18
# 5  Krisna Svnr & Lounge M  Purchase       NaN   -3.59
# 6   Krisna Oleh Oleh Bali  Purchase       NaN  -36.61
# 7                    Grab  Purchase       NaN   -4.09
# 8                    Grab  Purchase       NaN   -0.84
# 9                    Grab  Purchase       NaN   -4.74
#
#                                      other_details  account_id user  \
# 0    IDR 840,950.00 | FX rate £1 = IDR 23,477.4851    33053200  Taj
# 1    IDR 155,550.00 | FX rate £1 = IDR 23,462.0618    33053200  Taj
# 2     IDR 42,350.00 | FX rate £1 = IDR 23,528.3046    33053200  Taj
# 3    IDR 272,250.00 | FX rate £1 = IDR 23,592.1391    33053200  Taj
# 4  IDR 1,497,050.00 | FX rate £1 = IDR 23,695.5595    33053200  Taj
# 5     IDR 85,000.00 | FX rate £1 = IDR 23,677.0451    33053200  Taj
# 6    IDR 867,500.00 | FX rate £1 = IDR 23,696.1209    33053200  Taj
# 7     IDR 97,300.00 | FX rate £1 = IDR 23,790.2650    33053200  Taj
# 8     IDR 20,000.00 | FX rate £1 = IDR 23,809.5238    33053200  Taj
# 9    IDR 112,800.00 | FX rate £1 = IDR 23,797.6250    33053200  Taj
#
#              raw_merchant  raw_amount        bank
# 0               Samanvaya      -35.82  Chase Bank
# 1  Equipoise Resort & Spa       -6.63  Chase Bank
# 2               Samanvaya       -1.80  Chase Bank
# 3               Samanvaya      -11.54  Chase Bank
# 4               Samanvaya      -63.18  Chase Bank
# 5  Krisna Svnr & Lounge M       -3.59  Chase Bank
# 6   Krisna Oleh Oleh Bali      -36.61  Chase Bank
# 7                    Grab       -4.09  Chase Bank
# 8                    Grab       -0.84  Chase Bank
# 9                    Grab       -4.74  Chase Bank

# %%
transactions_df.shape
# Out:
# (65, 12)

# %%
transactions.upload_transactions_to_db(transactions_df, db_client)
# Out:
# APIResponse(data=[{'event_id': '32be75dda07543c23283228d4342b3b38838590919e9a6678f745a3f86004e03', 'date': '2026-07-01', 'merchant': 'Samanvaya', 'type': 'Purchase', 'category': None, 'amount': -35.82, 'other_details': 'IDR 840,950.00 | FX rate £1 = IDR 23,477.4851', 'account_id': 33053200, 'user': 'Taj', 'raw_merchant': 'Samanvaya', 'raw_amount': -35.82, 'bank': 'Chase Bank', 'updated_at': '2026-08-20T15:14:34.34129+00:00'}, {'event_id': 'b404beb6dd8ed159f2a4ff8921a33c380d0296d5670d524023bdc2c3400f6475', 'date': '2026-07-01', 'merchant': 'Equipoise Resort & Spa', 'type': 'Purchase', 'category': None, 'amount': -6.63, 'other_details': 'IDR 155,550.00 | FX rate £1 = IDR 23,462.0618', 'account_id': 33053200, 'user': 'Taj', 'raw_merchant': 'Equipoise Resort & Spa', 'raw_amount': -6.63, 'bank': 'Chase Bank', 'updated_at': '2026-08-20T15:14:34.34129+00:00'}, {'event_id': '799c91ecbf5ba6613b5e4bdc654cde7b4be779b033dce2dac56fc2796606f7d4', 'date': '2026-07-02', 'merchant': 'Samanvaya', 'type': 'Purchase', 'category': None, 'amount': -1.8, 'other_details': 'IDR 42,350.00 | FX rate £1 = IDR 23,528.3046', 'account_id': 33053200, 'user': 'Taj', 'raw_merchant': 'Samanvaya', 'raw_amount': -1.8, 'bank': 'Chase Bank', 'updated_at': '2026-08-20T15:14:34.34129+00:00'}, {'event_id': '8f853d47ff5f26aa3b2bb8c80951740773f73fb420a760a9098c73d349307213', 'date': '2026-07-02', 'merchant': 'Samanvaya', 'type': 'Purchase', 'category': None, 'amount': -11.54, 'other_details': 'IDR 272,250.00 | FX rate £1 = IDR 23,592.1391', 'account_id': 33053200, 'user': 'Taj', 'raw_merchant': 'Samanvaya', 'raw_amount': -11.54, 'bank': 'Chase Bank', 'updated_at': '2026-08-20T15:14:34.34129+00:00'}, {'event_id': '45a92998d423bb8a994a555f2df213a48779128bcde2d5b96b89d73848747337', 'date': '2026-07-03', 'merchant': 'Samanvaya', 'type': 'Purchase', 'category': None, 'amount': -63.18, 'other_details': 'IDR 1,497,050.00 | FX rate £1 = IDR 23,695.5595', 'account_id': 33053200, 'user': 'Taj', 'raw_merchant': 'Samanvaya', 'raw_amount': -63.18, 'bank': 'Chase Bank', 'updated_at': '2026-08-20T15:14:34.34129+00:00'}, {'event_id': 'c294d65759b5840c4573faefaf89c5382cb1c5178aa353a2aa0fb6bdfeb0381e', 'date': '2026-07-03', 'merchant': 'Krisna Svnr & Lounge M', 'type': 'Purchase', 'category': None, 'amount': -3.59, 'other_details': 'IDR 85,000.00 | FX rate £1 = IDR 23,677.0451', 'account_id': 33053200, 'user': 'Taj', 'raw_merchant': 'Krisna Svnr & Lounge M', 'raw_amount': -3.59, 'bank': 'Chase Bank', 'updated_at': '2026-08-20T15:14:34.34129+00:00'}, {'event_id': '60f39397c21309790ba457036cb751aa3dbe4005bdf84c0ed5d84c5826ba81d3', 'date': '2026-07-03', 'merchant': 'Krisna Oleh Oleh Bali', 'type': 'Purchase', 'category': None, 'amount': -36.61, 'other_details': 'IDR 867,500.00 | FX rate £1 = IDR 23,696.1209', 'account_id': 33053200, 'user': 'Taj', 'raw_merchant': 'Krisna Oleh Oleh Bali', 'raw_amount': -36.61, 'bank': 'Chase Bank', 'updated_at': '2026-08-20T15:14:34.34129+00:00'}, {'event_id': 'de64913b0df7e9b86868430712e47b0d4c9c4b0b556beaddd8701ed975661dc8', 'date': '2026-07-04', 'merchant': 'Grab', 'type': 'Purchase', 'category': None, 'amount': -4.09, 'other_details': 'IDR 97,300.00 | FX rate £1 = IDR 23,790.2650', 'account_id': 33053200, 'user': 'Taj', 'raw_merchant': 'Grab', 'raw_amount': -4.09, 'bank': 'Chase Bank', 'updated_at': '2026-08-20T15:14:34.34129+00:00'}, {'event_id': '2fa016d301a22588e5bb87084311786bff383548948d7d0bfe6c6d739a9dd2c6', 'date': '2026-07-04', 'merchant': 'Grab', 'type': 'Purchase', 'category': None, 'amount': -0.84, 'other_details': 'IDR 20,000.00 | FX rate £1 = IDR 23,809.5238', 'account_id': 33053200, 'user': 'Taj', 'raw_merchant': 'Grab', 'raw_amount': -0.84, 'bank': 'Chase Bank', 'updated_at': '2026-08-20T15:14:34.34129+00:00'}, {'event_id': '140650226632d10a80d6e2b5222a274956d4944a20e3cd98de94175252ad83e6', 'date': '2026-07-04', 'merchant': 'Grab', 'type': 'Purchase', 'category': None, 'amount': -4.74, 'other_details': 'IDR 112,800.00 | FX rate £1 = IDR 23 ...
