# %%
from spending_tracker.database import supabase_client
from spending_tracker.database import transactions
from spending_tracker.data_ingestion import csv_parsing
from pathlib import Path
import pandas as pd

# %%
db_client = supabase_client.load_supabase_client()

# %%
processed_transactions_data_home = Path().resolve().parent / "data" / "transactions" / "processed"
print(processed_transactions_data_home)
# Out:
# /Users/taj/Documents/Spending-Tracker-Agent/data/transactions/processed

# %%
transactions_df = csv_parsing.load_processed_transactions(processed_transactions_data_home)

# %%
transactions_df.head(10)
# Out:
#                                             event_id        date    month  \
# 0  1250520dee7b2ebf2b2de5a853dcb675c7fae27002bf87...  2026-07-28  July-26
# 1  a7a47f104cc12aa1e396154fc9c549a1daa25529236f2a...  2026-07-23  July-26
# 2  72a27fac5109a6f45a5a75c01a085ddebbaca39b0530e1...  2026-07-22  July-26
# 3  6d9e7057569a93dabe6dc513d424eb0b374407b29f94c2...  2026-07-20  July-26
# 4  e8ff32ca9b78bc7f629c82b6132902143ab3085a9ac628...  2026-07-18  July-26
# 5  a28686276e50e0ba6077557bbb4b15fcfcc273a8190cd7...  2026-07-18  July-26
# 6  ea3edcd77678cf05ea790b3e28054ea2d9809c4ce923c1...  2026-07-14  July-26
# 7  9695cc15562e0dcff877216ef66f515a6e32e87c0706ea...  2026-07-13  July-26
# 8  aedf6d7e3c48b009d422638b47f3c4e9aaa9efb1466a90...  2026-07-30  July-26
# 9  d4a85289271656773648c9e632698c43290e30bd726ab9...  2026-07-30  July-26
#
#                   merchant type  category  amount  other_details  account_id  \
# 0  WM MORRISONS STORES - Q  NaN       NaN   -6.50         LONDON       51016
# 1  WM MORRISONS STORES - Q  NaN       NaN   -3.50         LONDON       51016
# 2  FS2307 Queensbury 73156  NaN       NaN  -60.00       Stanmore       51016
# 3  TESCO STORE 2126 2126TE  NaN       NaN   -4.50    BOREHAMWOOD       51016
# 4   AMAZON.CO.UK*5Q00B9ZR5  NaN       NaN  -39.42   AMAZON.CO.UK       51016
# 5              ASDA STORES  NaN       NaN  -11.00         LONDON       51016
# 6  TESCO STORE 2126 2126TE  NaN       NaN   -8.00    BOREHAMWOOD       51016
# 7   AMZNMKTPLACE*SC2GE5OF5  NaN       NaN  -18.99   AMAZON.CO.UK       51016
# 8       BOND DENTAL LONDON  NaN       NaN   95.00         LONDON       52006
# 9        TFL TRAVEL CHARGE  NaN       NaN   -8.40  TFL.GOV.UK/CP       52006
#
#       user             raw_merchant  raw_amount  bank  hidden
# 0  Radhika  WM MORRISONS STORES - Q       -6.50  Amex   False
# 1  Radhika  WM MORRISONS STORES - Q       -3.50  Amex   False
# 2  Radhika  FS2307 Queensbury 73156      -60.00  Amex   False
# 3  Radhika  TESCO STORE 2126 2126TE       -4.50  Amex   False
# 4  Radhika   AMAZON.CO.UK*5Q00B9ZR5      -39.42  Amex   False
# 5  Radhika              ASDA STORES      -11.00  Amex   False
# 6  Radhika  TESCO STORE 2126 2126TE       -8.00  Amex   False
# 7  Radhika   AMZNMKTPLACE*SC2GE5OF5      -18.99  Amex   False
# 8      Taj       BOND DENTAL LONDON       95.00  Amex   False
# 9      Taj        TFL TRAVEL CHARGE       -8.40  Amex   False

# %%
transactions_df.shape
# Out:
# (120, 14)

# %%
transactions.upload_transactions_to_db(transactions_df, db_client)
# Out:
# APIResponse(data=[{'event_id': '1250520dee7b2ebf2b2de5a853dcb675c7fae27002bf87c6ef0765566813ccc7', 'date': '2026-07-28', 'merchant': 'WM MORRISONS STORES - Q', 'type': None, 'category': None, 'amount': -6.5, 'other_details': 'LONDON', 'account_id': 51016, 'user': 'Radhika', 'raw_merchant': 'WM MORRISONS STORES - Q', 'raw_amount': -6.5, 'bank': 'Amex', 'updated_at': '2026-08-25T11:48:00.66236+00:00', 'hidden': False, 'month': 'July-26'}, {'event_id': 'a7a47f104cc12aa1e396154fc9c549a1daa25529236f2af80030f1a5163c111d', 'date': '2026-07-23', 'merchant': 'WM MORRISONS STORES - Q', 'type': None, 'category': None, 'amount': -3.5, 'other_details': 'LONDON', 'account_id': 51016, 'user': 'Radhika', 'raw_merchant': 'WM MORRISONS STORES - Q', 'raw_amount': -3.5, 'bank': 'Amex', 'updated_at': '2026-08-25T11:48:00.66236+00:00', 'hidden': False, 'month': 'July-26'}, {'event_id': '72a27fac5109a6f45a5a75c01a085ddebbaca39b0530e1fe4bde6611f3299412', 'date': '2026-07-22', 'merchant': 'FS2307 Queensbury 73156', 'type': None, 'category': None, 'amount': -60.0, 'other_details': 'Stanmore', 'account_id': 51016, 'user': 'Radhika', 'raw_merchant': 'FS2307 Queensbury 73156', 'raw_amount': -60.0, 'bank': 'Amex', 'updated_at': '2026-08-25T11:48:00.66236+00:00', 'hidden': False, 'month': 'July-26'}, {'event_id': '6d9e7057569a93dabe6dc513d424eb0b374407b29f94c234dd20b70217c9bc13', 'date': '2026-07-20', 'merchant': 'TESCO STORE 2126 2126TE', 'type': None, 'category': None, 'amount': -4.5, 'other_details': 'BOREHAMWOOD', 'account_id': 51016, 'user': 'Radhika', 'raw_merchant': 'TESCO STORE 2126 2126TE', 'raw_amount': -4.5, 'bank': 'Amex', 'updated_at': '2026-08-25T11:48:00.66236+00:00', 'hidden': False, 'month': 'July-26'}, {'event_id': 'e8ff32ca9b78bc7f629c82b6132902143ab3085a9ac6283ba1cbf4eb319141f3', 'date': '2026-07-18', 'merchant': 'AMAZON.CO.UK*5Q00B9ZR5', 'type': None, 'category': None, 'amount': -39.42, 'other_details': 'AMAZON.CO.UK', 'account_id': 51016, 'user': 'Radhika', 'raw_merchant': 'AMAZON.CO.UK*5Q00B9ZR5', 'raw_amount': -39.42, 'bank': 'Amex', 'updated_at': '2026-08-25T11:48:00.66236+00:00', 'hidden': False, 'month': 'July-26'}, {'event_id': 'a28686276e50e0ba6077557bbb4b15fcfcc273a8190cd7222ebb0379a55bd90e', 'date': '2026-07-18', 'merchant': 'ASDA STORES', 'type': None, 'category': None, 'amount': -11.0, 'other_details': 'LONDON', 'account_id': 51016, 'user': 'Radhika', 'raw_merchant': 'ASDA STORES', 'raw_amount': -11.0, 'bank': 'Amex', 'updated_at': '2026-08-25T11:48:00.66236+00:00', 'hidden': False, 'month': 'July-26'}, {'event_id': 'ea3edcd77678cf05ea790b3e28054ea2d9809c4ce923c165283608cabce32214', 'date': '2026-07-14', 'merchant': 'TESCO STORE 2126 2126TE', 'type': None, 'category': None, 'amount': -8.0, 'other_details': 'BOREHAMWOOD', 'account_id': 51016, 'user': 'Radhika', 'raw_merchant': 'TESCO STORE 2126 2126TE', 'raw_amount': -8.0, 'bank': 'Amex', 'updated_at': '2026-08-25T11:48:00.66236+00:00', 'hidden': False, 'month': 'July-26'}, {'event_id': '9695cc15562e0dcff877216ef66f515a6e32e87c0706eaad1b63f9222bfb6203', 'date': '2026-07-13', 'merchant': 'AMZNMKTPLACE*SC2GE5OF5', 'type': None, 'category': None, 'amount': -18.99, 'other_details': 'AMAZON.CO.UK', 'account_id': 51016, 'user': 'Radhika', 'raw_merchant': 'AMZNMKTPLACE*SC2GE5OF5', 'raw_amount': -18.99, 'bank': 'Amex', 'updated_at': '2026-08-25T11:48:00.66236+00:00', 'hidden': False, 'month': 'July-26'}, {'event_id': 'aedf6d7e3c48b009d422638b47f3c4e9aaa9efb1466a90ac72bd851c266aeb35', 'date': '2026-07-30', 'merchant': 'BOND DENTAL LONDON', 'type': None, 'category': None, 'amount': 95.0, 'other_details': 'LONDON', 'account_id': 52006, 'user': 'Taj', 'raw_merchant': 'BOND DENTAL LONDON', 'raw_amount': 95.0, 'bank': 'Amex', 'updated_at': '2026-08-25T11:48:00.66236+00:00', 'hidden': False, 'month': 'July-26'}, {'event_id': 'd4a85289271656773648c9e632698c43290e30bd726ab97971b200b122fbc8d4', 'date': '2026-07-30', 'merchant': 'TFL TRAVEL CHARGE', 'type': None, 'category': None, 'amount': -8. ...
