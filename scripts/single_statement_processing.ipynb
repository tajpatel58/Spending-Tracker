# %%
from pathlib import Path
from spending_tracker.data_processing.statements import parse_and_clean_batch

# %%
data_path = Path().resolve().parent / "data"

# %%
user = "Joint"
bank = "Nationwide"
account_id = "34490057"
month = "August-26"

# %%
parse_and_clean_batch(data_home=data_path,
                      specific_month=month)
# Out:
# ('Joint', 'Nationwide', '03076275', 'August-26', 'statement.csv')
# ('Joint', 'Nationwide', '03076275', 'July-26', 'statement.csv')
# ('Radhika', 'Nationwide', '34490057', 'August-26', 'statement.csv')
# ('Radhika', 'Nationwide', '34490057', 'July-26', 'statement.csv')
# ('Taj', 'Amex', '52006', 'August-26', 'statement.csv')
# ('Taj', 'Amex', '52006', 'July-26', 'statement.csv')
# ('Taj', 'Chase', '33053200', 'August-26', 'statement.pdf')
# ('Taj', 'Chase', '33053200', 'July-26', 'statement.pdf')
# ('Taj', 'Chase', '69448147', 'August-26', 'statement.pdf')
# ('Taj', 'Chase', '69448147', 'July-26', 'statement.pdf')
# Processing Joint/Nationwide/03076275/August-26
